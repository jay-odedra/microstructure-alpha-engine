# %% [markdown]
# ### Baseline: Move + Direction
#
# - Split into two models:
#   - **P(move)** → is there any price change
#   - **P(up | move)** → direction given a move
#
# - Move model = market activity (vol, trades, liquidity) e
# - Direction model = order flow / imbalance
#
# - Combine:
#   **P(up) = P(move) × P(up | move)**
#
# - Keeps activity and direction separate
#
#
# ### Feature Selection
#
# - Use **move model** to find what drives activity
#
# - L1 reg to find which sets of features predict moves
#
# - Group related features (e.g. imbalance, depth, trades)
#
# - L2 on grouped set - to see which features best within the group
#
# - Goal: identify **important feature classes**, not just single features

# %%
import pandas as pd
import numpy as np
from binance.client import Client
import time
import black
from pympler import asizeof
import math
import matplotlib.pyplot as plt
import glob

# %%
target = "mid_price_moves"

# %%
files_final = glob.glob(
    "C:\\Users\\jayod\\Documents\\Quant_Project\\microstructure-alpha-engine\\data\\ml_ready_data\\ml_ready.parquet"
)

final_dataset = pd.concat([pd.read_parquet(f) for f in files_final])

# %%
final_dataset = final_dataset.sort_values("timestamp").reset_index(drop=True)

final_dataset = final_dataset.dropna().reset_index(drop=True)

final_dataset[target].value_counts()
# Out:
# mid_price_moves
# 0    25213
# 1    18786
# Name: count, dtype: int64

# %% [markdown]
# # Full feature list

# %%
lob_features = [
    # "lob_bids_price_1",
    # "lob_bids_price_2",
    # "lob_bids_price_3",
    # "lob_bids_price_4",
    # "lob_bids_price_5",
    # "lob_bids_price_6",
    # "lob_bids_price_7",
    # "lob_bids_price_8",
    # "lob_bids_price_9",
    # "lob_bids_price_10",
    # "lob_bids_volume_1",
    # "lob_bids_volume_2",
    # "lob_bids_volume_3",
    # "lob_bids_volume_4",
    # "lob_bids_volume_5",
    # "lob_bids_volume_6",
    # "lob_bids_volume_7",
    # "lob_bids_volume_8",
    # "lob_bids_volume_9",
    # "lob_bids_volume_10",
    # "lob_asks_price_1",
    # "lob_asks_price_2",
    # "lob_asks_price_3",
    # "lob_asks_price_4",
    # "lob_asks_price_5",
    # "lob_asks_price_6",
    # "lob_asks_price_7",
    # "lob_asks_price_8",
    # "lob_asks_price_9",
    # "lob_asks_price_10",
    # "lob_asks_volume_1",
    # "lob_asks_volume_2",
    # "lob_asks_volume_3",
    # "lob_asks_volume_4",
    # "lob_asks_volume_5",
    # "lob_asks_volume_6",
    # "lob_asks_volume_7",
    # "lob_asks_volume_8",
    # "lob_asks_volume_9",
    # "lob_asks_volume_10",
    "lob_depth_ratio_2",
    "lob_depth_ratio_3",
    "lob_depth_ratio_4",
    "lob_depth_ratio_5",
    "lob_depth_ratio_6",
    "lob_depth_ratio_7",
    "lob_depth_ratio_8",
    "lob_depth_ratio_9",
    "lob_depth_ratio_10",
]

spread_features = [
    # "rel_spread",
    # "spread"
]
imbalance_features = [
    "imbalance_1",
    "imbalance_5",
    "imbalance_10",
    "imbalance_depth_1",
    "imbalance_depth_2",
    "imbalance_depth_3",
    "imbalance_depth_4",
    "imbalance_depth_5",
    "imbalance_depth_6",
    "imbalance_depth_7",
    "imbalance_depth_8",
    "imbalance_depth_9",
    "imbalance_depth_10",
]
liquidity_features = [
    # "liquidity",
    # "total_bid_volume_10",
    # "total_ask_volume_10",
    # "total_book_volume",
    # "max_bid_ask_vol_ratio",
]
microprice_features = [
    "microprice",
    "microprice_change",
    # "mid_minus_micro",
    "microprice_weighted_10",
]
return_features = [
    # "return_1",
    # "return_5",
    "log_return_1",
    "log_return_2",
    "log_return_3",
    "log_return_5",
    "log_return_20",
    "mid_price_change_1",
    "mid_price_change_5",
    "mid_price_change_20",
]
momentum_features = [
    "momentum_5_log_return_1",
    "momentum_20_log_return_1",
]
volatility_features = [
    # "vol_5",
    # "vol_20",
    # "realized_vol_5",
    # "realized_vol_20",
]
trade_activity_features = [
    # "trade_count",
    #    "buy_count",
    #        "sell_count",
]
trade_volume_features = [
    #   "total_trade_volume",
    #   "buy_volume",
    #   "sell_volume",
    #   "avg_trade_size",
    #   "max_trade_size",
    #   "min_trade_size",
    #   "std_trade_size",
    #   "max_over_average",
]
trade_flow_features = [
    "trade_volume_imbalance",
]
trade_dynamics_features = [
    "trade_volume_change",
    "trade_count_change",
]
lagged_trade_features = [
    "lag_trade_volume_imbalance_1",
    "lag_trade_volume_imbalance_2",
    "lag_trade_volume_imbalance_3",
    "lag_trade_volume_imbalance_5",
]
feature_groups = {
    "lob_features": lob_features,
    "spread": spread_features,
    "imbalance": imbalance_features,
    "liquidity": liquidity_features,
    "microprice": microprice_features,
    "returns": return_features,
    "momentum": momentum_features,
    "volatility": volatility_features,
    "trade_activity": trade_activity_features,
    "trade_volume": trade_volume_features,
    "trade_flow": trade_flow_features,
    "trade_dynamics": trade_dynamics_features,
    "lagged_trade": lagged_trade_features,
}
all_features = (
    lob_features
    + spread_features
    + imbalance_features
    + liquidity_features
    + microprice_features
    + return_features
    + momentum_features
    + volatility_features
    + trade_activity_features
    + trade_volume_features
    + trade_flow_features
    + trade_dynamics_features
    + lagged_trade_features
)

# %%
transformed = [
    "lob_bids_volume_1_log1p",
    "lob_bids_volume_2_log1p",
    "lob_bids_volume_3_log1p",
    "lob_bids_volume_4_log1p",
    "lob_bids_volume_5_log1p",
    "lob_bids_volume_6_log1p",
    "lob_bids_volume_7_log1p",
    "lob_bids_volume_8_log1p",
    "lob_bids_volume_9_log1p",
    "lob_bids_volume_10_log1p",
    "rel_spread_log1p",
    "spread_log1p",
    "liquidity_log1p",
    "total_bid_volume_10_log1p",
    "total_ask_volume_10_log1p",
    "total_book_volume_log1p",
    "max_bid_ask_vol_ratio_log1p",
    "mid_minus_micro_log1p",
    "vol_5_log1p",
    "vol_20_log1p",
    "realized_vol_5_log1p",
    "realized_vol_20_log1p",
    "trade_count_log1p",
    "buy_count_log1p",
    "sell_count_log1p",
    "total_trade_volume_log1p",
    "buy_volume_log1p",
    "sell_volume_log1p",
    "avg_trade_size_log1p",
    "max_trade_size_log1p",
    "min_trade_size_log1p",
    "std_trade_size_log1p",
    "max_over_average_log1p",
]

# %%
features = all_features + transformed
print(features)
# Out:
# ['lob_depth_ratio_2', 'lob_depth_ratio_3', 'lob_depth_ratio_4', 'lob_depth_ratio_5', 'lob_depth_ratio_6', 'lob_depth_ratio_7', 'lob_depth_ratio_8', 'lob_depth_ratio_9', 'lob_depth_ratio_10', 'imbalance_1', 'imbalance_5', 'imbalance_10', 'imbalance_depth_1', 'imbalance_depth_2', 'imbalance_depth_3', 'imbalance_depth_4', 'imbalance_depth_5', 'imbalance_depth_6', 'imbalance_depth_7', 'imbalance_depth_8', 'imbalance_depth_9', 'imbalance_depth_10', 'microprice', 'microprice_change', 'microprice_weighted_10', 'log_return_1', 'log_return_2', 'log_return_3', 'log_return_5', 'log_return_20', 'mid_price_change_1', 'mid_price_change_5', 'mid_price_change_20', 'momentum_5_log_return_1', 'momentum_20_log_return_1', 'trade_volume_imbalance', 'trade_volume_change', 'trade_count_change', 'lag_trade_volume_imbalance_1', 'lag_trade_volume_imbalance_2', 'lag_trade_volume_imbalance_3', 'lag_trade_volume_imbalance_5', 'lob_bids_volume_1_log1p', 'lob_bids_volume_2_log1p', 'lob_bids_volume_3_log1p', 'lob_bids_volume_4_log1p', 'lob_bids_volume_5_log1p', 'lob_bids_volume_6_log1p', 'lob_bids_volume_7_log1p', 'lob_bids_volume_8_log1p', 'lob_bids_volume_9_log1p', 'lob_bids_volume_10_log1p', 'rel_spread_log1p', 'spread_log1p', 'liquidity_log1p', 'total_bid_volume_10_log1p', 'total_ask_volume_10_log1p', 'total_book_volume_log1p', 'max_bid_ask_vol_ratio_log1p', 'mid_minus_micro_log1p', 'vol_5_log1p', 'vol_20_log1p', 'realized_vol_5_log1p', 'realized_vol_20_log1p', 'trade_count_log1p', 'buy_count_log1p', 'sell_count_log1p', 'total_trade_volume_log1p', 'buy_volume_log1p', 'sell_volume_log1p', 'avg_trade_size_log1p', 'max_trade_size_log1p', 'min_trade_size_log1p', 'std_trade_size_log1p', 'max_over_average_log1p']

# %% [markdown]
# # Splitting data

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score

# %%
tscv = TimeSeriesSplit(n_splits=10, gap=50)

# %% [markdown]
# # l1 training for feature selection

# %% [markdown]
# Data

# %%
X = final_dataset[features]
y = final_dataset[target]

# %% [markdown]
# model

# %%
model = LogisticRegression(
    l1_ratio=1,
    solver="saga",
    C=1.0,
    max_iter=5000,
)

# %%
from joblib import Parallel, delayed


def run_move_fold(train_idx, test_idx, X_move, y_move, model):
    from copy import deepcopy

    model = deepcopy(model)

    oof = np.full(len(X_move), np.nan)

    X_train = X_move.iloc[train_idx].copy()
    X_test = X_move.iloc[test_idx].copy()

    y_train = y_move.iloc[train_idx]
    y_test = y_move.iloc[test_idx]

    lower = X_train.quantile(0.01)
    upper = X_train.quantile(0.99)

    X_train = X_train.clip(lower, upper, axis=1)
    X_test = X_test.clip(lower, upper, axis=1)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)

    model.fit(X_train, y_train)
    p = model.predict_proba(X_test)[:, 1]

    oof[test_idx] = p

    auc = roc_auc_score(y_test, p)

    coef = model.coef_[0]

    return oof, auc, coef

# %%
def run_move_model_parallel(X_move, y_move, model_class, tscv, n_jobs=4):

    results = Parallel(n_jobs=n_jobs)(
        delayed(run_move_fold)(train_idx, test_idx, X_move, y_move, model_class)
        for train_idx, test_idx in tscv.split(X_move)
    )

    oof_preds, fold_aucs, fold_coefs = zip(*results)

    return list(oof_preds), list(fold_aucs), list(fold_coefs)

# %%
oof_preds, fold_aucs, fold_coefs = run_move_model_parallel(X, y, model, tscv, n_jobs=8)

# %%
print(fold_aucs)
plt.figure(figsize=(8, 4))

plt.plot(fold_aucs, marker="o")

plt.xlabel("Fold")
plt.ylabel("AUC")
plt.legend()
plt.title("AUC per Fold")
# Out:
# [0.7533542534607325, 0.8138604771481686, 0.66833805869562, 0.6929340275680442, 0.6838187214929407, 0.7069267835363261, 0.6700224779999989, 0.7122553958435575, 0.6663817452058868, 0.7839516017949963]
# C:\Users\jayod\AppData\Local\Temp\ipykernel_5808\1034978923.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0.5, 1.0, 'AUC per Fold')

# %%
final_preds = np.nansum(oof_preds, axis=0)
y_true = y.values

# %%
import matplotlib.pyplot as plt

window = 500

pred_smooth = pd.Series(final_preds).rolling(window).mean()
target_smooth = pd.Series(y_true).rolling(window).mean()

plt.figure(figsize=(12, 4))
plt.plot(pred_smooth, label="Predicted prob (smoothed)")
plt.plot(target_smooth, label="True (rolling)", alpha=0.8)
plt.legend()
plt.title(f"Rolling Calibration (window={window})")
# Out:
# Text(0.5, 1.0, 'Rolling Calibration (window=500)')

# %%
plt.hist(final_preds, bins=50)
plt.title("Prediction distribution")
# Out:
# Text(0.5, 1.0, 'Prediction distribution')

# %%
import pandas as pd

avg_coefs = pd.Series(np.mean(fold_coefs, axis=0), index=features)
avg_coefs = avg_coefs.sort_values(key=abs, ascending=False)
pd.set_option("display.max_rows", None)
print(avg_coefs)
# Out:
# rel_spread_log1p                8.580802
# microprice                      4.228790
# microprice_weighted_10          4.174153
# realized_vol_20_log1p           1.341962
# trade_count_log1p               0.890636
# vol_20_log1p                   -0.749597
# total_ask_volume_10_log1p      -0.666096
# max_trade_size_log1p            0.539309
# max_over_average_log1p         -0.517043
# std_trade_size_log1p           -0.486780
# total_book_volume_log1p         0.469967
# total_bid_volume_10_log1p      -0.411277
# max_bid_ask_vol_ratio_log1p     0.397924
# trade_count_change              0.338114
# lob_bids_volume_1_log1p        -0.282042
# realized_vol_5_log1p            0.227352
# total_trade_volume_log1p        0.174894
# avg_trade_size_log1p           -0.153304
# min_trade_size_log1p           -0.133468
# imbalance_depth_5              -0.124783
# buy_count_log1p                -0.124162
# imbalance_10                   -0.124122
# lob_depth_ratio_2              -0.121748
# lob_depth_ratio_5               0.115792
# imbalance_depth_2               0.106556
# lob_depth_ratio_3              -0.104748
# trade_volume_change            -0.096507
# lob_bids_volume_3_log1p         0.081587
# sell_volume_log1p              -0.081012
# imbalance_depth_4               0.080203
# imbalance_5                     0.074227
# lob_depth_ratio_4              -0.073001
# liquidity_log1p                -0.066628
# vol_5_log1p                    -0.063208
# sell_count_log1p               -0.039975
# imbalance_depth_1              -0.036099
# imbalance_1                    -0.036099
# mid_price_change_1             -0.033561
# trade_volume_imbalance          0.031913
# mid_price_change_20             0.030753
# lob_bids_volume_6_log1p         0.029530
# imbalance_depth_9              -0.028646
# lob_bids_volume_8_log1p        -0.024725
# microprice_change               0.024598
# log_return_2                   -0.022690
# imbalance_depth_3               0.022456
# lob_depth_ratio_10             -0.022257
# imbalance_depth_7              -0.021415
# lag_trade_volume_imbalance_1    0.019068
# lag_trade_volume_imbalance_5    0.018898
# mid_price_change_5             -0.018004
# lob_bids_volume_4_log1p        -0.017208
# lob_bids_volume_5_log1p        -0.017122
# momentum_5_log_return_1         0.014349
# log_return_5                    0.014349
# lob_bids_volume_2_log1p         0.013289
# spread_log1p                   -0.012483
# lob_depth_ratio_6              -0.011575
# imbalance_depth_6              -0.011474
# lob_bids_volume_10_log1p       -0.010861
# lob_bids_volume_7_log1p        -0.010648
# log_return_1                    0.010090
# imbalance_depth_8              -0.008897
# lob_depth_ratio_8               0.008672
# log_return_3                    0.005404
# lag_trade_volume_imbalance_2    0.004486
# lag_trade_volume_imbalance_3   -0.004091
# lob_bids_volume_9_log1p         0.003738
# buy_volume_log1p               -0.003393
# momentum_20_log_return_1        0.002537
# log_return_20                   0.002537
# mid_minus_micro_log1p          -0.000882
# imbalance_depth_10              0.000832
# lob_depth_ratio_9               0.000348
# lob_depth_ratio_7              -0.000011
# dtype: float64

# %%
sorted_tables = []

for i in range(len(fold_coefs)):
    s = pd.Series(fold_coefs[i], index=features)
    s = s.sort_values(key=abs, ascending=False)

    df_fold = pd.DataFrame({f"Fold_{i}_feature": s.index, f"Fold_{i}_coef": s.values})

    sorted_tables.append(df_fold.reset_index(drop=True))

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)


coef_table = pd.concat(sorted_tables, axis=1)

print(coef_table)
# Out:
#                   Fold_0_feature  Fold_0_coef                Fold_1_feature  Fold_1_coef                Fold_2_feature  Fold_2_coef                Fold_3_feature  Fold_3_coef                Fold_4_feature  Fold_4_coef                Fold_5_feature  Fold_5_coef                Fold_6_feature  Fold_6_coef                Fold_7_feature   Fold_7_coef                Fold_8_feature  Fold_8_coef                Fold_9_feature  Fold_9_coef
# 0              trade_count_log1p     1.660069             trade_count_log1p     1.374957         realized_vol_20_log1p     1.655541         realized_vol_20_log1p     1.709615              rel_spread_log1p    14.276567              rel_spread_log1p    17.123929              rel_spread_log1p    16.420755              rel_spread_log1p  1.522427e+01              rel_spread_log1p    12.181020              rel_spread_log1p     9.510080
# 1           max_trade_size_log1p     0.991705         realized_vol_20_log1p     1.296528             trade_count_log1p     1.234130             trade_count_log1p     1.185636                    microprice     7.033230        microprice_weighted_10     8.472746                    microprice     8.116240                    microprice  7.666343e+00                    microprice     6.117839                    microprice     4.792982
# 2           std_trade_size_log1p    -0.903692                  vol_20_log1p    -1.076111                  vol_20_log1p    -1.126788                  vol_20_log1p    -0.907719        microprice_weighted_10     7.019779                    microprice     8.458657        microprice_weighted_10     8.095056        microprice_weighted_10  7.365214e+00        microprice_weighted_10     5.975149        microprice_weighted_10     4.705942
# 3         max_over_average_log1p    -0.810621          std_trade_size_log1p    -0.763729     total_ask_volume_10_log1p    -0.604908     total_ask_volume_10_log1p    -0.702441         realized_vol_20_log1p     1.490159         realized_vol_20_log1p     1.509157         realized_vol_20_log1p     1.505298         realized_vol_20_log1p  1.336338e+00         realized_vol_20_log1p     1.345290         realized_vol_20_log1p     1.290660
# 4      total_ask_volume_10_log1p    -0.534907          max_trade_size_log1p     0.654493              rel_spread_log1p     0.566125     total_bid_volume_10_log1p    -0.654358             trade_count_log1p     0.978481                  vol_20_log1p    -0.815868                  vol_20_log1p    -0.860642                  vol_20_log1p -6.944941e-01     total_ask_volume_10_log1p    -0.746709     total_bid_volume_10_log1p    -0.766052
# 5        lob_bids_volume_1_log1p    -0.481438        max_over_average_log1p    -0.593596          std_trade_size_log1p    -0.545130          max_trade_size_log1p     0.636479     total_ask_volume_10_log1p    -0.724071             trade_count_log1p     0.814811     total_ask_volume_10_log1p    -0.764645     total_ask_volume_10_log1p -6.724027e-01                  vol_20_log1p    -0.696103     total_ask_volume_10_log1p    -0.690073
# 6    max_bid_ask_vol_ratio_log1p     0.447524   max_bid_ask_vol_ratio_log1p     0.553026       lob_bids_volume_1_log1p    -0.520616        max_over_average_log1p    -0.573299                  vol_20_log1p    -0.715473     total_ask_volume_10_log1p    -0.748905             trade_count_log1p     0.682200     total_bid_volume_10_log1p -5.986109e-01     total_bid_volume_10_log1p    -0.600432                  vol_20_log1p    -0.602767
# 7              lob_depth_ratio_5     0.372542       lob_bids_volume_1_log1p    -0.537531          max_trade_size_log1p     0.513875          std_trade_size_log1p    -0.552357          max_trade_size_log1p     0.623081        max_over_average_log1p    -0.547986       total_book_volume_log1p     0.565558       total_book_volume_log1p  5.441127e-01       total_book_volume_log1p     0.580606       total_book_volume_log1p     0.593170
# 8             trade_count_change     0.372495     total_ask_volume_10_log1p    -0.471896        max_over_average_log1p    -0.493607       total_book_volume_log1p     0.485892        max_over_average_log1p    -0.622791       total_book_volume_log1p     0.543756        max_over_average_log1p    -0.523803             trade_count_log1p  4.594870e-01   max_bid_ask_vol_ratio_log1p     0.339380   max_bid_ask_vol_ratio_log1p     0.354664
# 9              imbalance_depth_5    -0.321523            trade_count_change     0.377670          realized_vol_5_log1p     0.491490            trade_count_change     0.398143       total_book_volume_log1p     0.541962          max_trade_size_log1p     0.490277     total_bid_volume_10_log1p    -0.482464        max_over_average_log1p -3.935431e-01        max_over_average_log1p    -0.329041          max_trade_size_log1p     0.351799
# 10       total_book_volume_log1p     0.315095       total_book_volume_log1p     0.259798   max_bid_ask_vol_ratio_log1p     0.461541              rel_spread_log1p     0.373286     total_bid_volume_10_log1p    -0.537006     total_bid_volume_10_log1p    -0.462703          max_trade_size_log1p     0.440944          max_trade_size_log1p  3.680117e-01          max_trade_size_log1p     0.322429        max_over_average_log1p    -0.282138
# 11         realized_vol_20_log1p     0.281038               buy_count_log1p    -0.218589            trade_count_change     0.420097   max_bid_ask_vol_ratio_log1p     0.370254          std_trade_size_log1p    -0.477414          std_trade_size_log1p    -0.433841          std_trade_size_log1p    -0.364384   max_bid_ask_vol_ratio_log1p  3.584065e-01             trade_count_log1p     0.313121            trade_count_change     0.244728
# 12             imbalance_depth_4     0.238233          realized_vol_5_log1p     0.217362                  imbalance_10    -0.314085          realized_vol_5_log1p     0.285641            trade_count_change     0.382489   max_bid_ask_vol_ratio_log1p     0.373503   max_bid_ask_vol_ratio_log1p     0.347096          std_trade_size_log1p -3.089541e-01          std_trade_size_log1p    -0.289020          std_trade_size_log1p    -0.229282
# 13               buy_count_log1p    -0.229025             imbalance_depth_5    -0.168887                   vol_5_log1p    -0.310587      total_trade_volume_log1p     0.283256   max_bid_ask_vol_ratio_log1p     0.373849            trade_count_change     0.331229            trade_count_change     0.318045            trade_count_change  2.802622e-01            trade_count_change     0.255978          realized_vol_5_log1p     0.209285
# 14           mid_price_change_20     0.196900              sell_count_log1p    -0.146189       total_book_volume_log1p     0.269718               buy_count_log1p    -0.221555          avg_trade_size_log1p    -0.243755       lob_bids_volume_1_log1p    -0.261351       lob_bids_volume_1_log1p    -0.297938       lob_bids_volume_1_log1p -2.119527e-01       lob_bids_volume_1_log1p    -0.207595             trade_count_log1p     0.203471
# 15          min_trade_size_log1p    -0.180855             lob_depth_ratio_3    -0.145580               buy_count_log1p    -0.260526          avg_trade_size_log1p    -0.205564                  imbalance_10    -0.236594                  imbalance_10    -0.242234                  imbalance_10    -0.206499      total_trade_volume_log1p  2.111644e-01          realized_vol_5_log1p     0.201589          avg_trade_size_log1p    -0.184394
# 16             lob_depth_ratio_3    -0.169419          min_trade_size_log1p    -0.143434      total_trade_volume_log1p     0.258485              sell_count_log1p    -0.188230          realized_vol_5_log1p     0.234668      total_trade_volume_log1p     0.206236      total_trade_volume_log1p     0.197716          realized_vol_5_log1p  1.832048e-01      total_trade_volume_log1p     0.155751               liquidity_log1p    -0.134172
# 17            imbalance_depth_10    -0.167245              buy_volume_log1p     0.134950             lob_depth_ratio_3    -0.205545                   imbalance_5     0.185290      total_trade_volume_log1p     0.199924          avg_trade_size_log1p    -0.190343          avg_trade_size_log1p    -0.165893          avg_trade_size_log1p -1.678522e-01          avg_trade_size_log1p    -0.138846              sell_count_log1p     0.124964
# 18             lob_depth_ratio_4    -0.163178      total_trade_volume_log1p     0.134302             imbalance_depth_5    -0.168653             lob_depth_ratio_3    -0.146240       lob_bids_volume_1_log1p    -0.183205          realized_vol_5_log1p     0.185677          realized_vol_5_log1p     0.163495             lob_depth_ratio_2 -1.212836e-01          min_trade_size_log1p    -0.113251             imbalance_depth_1    -0.119188
# 19            mid_price_change_5    -0.120351             lob_depth_ratio_5     0.134148          avg_trade_size_log1p    -0.159488             lob_depth_ratio_2    -0.143544             lob_depth_ratio_2    -0.173063             lob_depth_ratio_2    -0.184238             lob_depth_ratio_2    -0.151747          min_trade_size_log1p -1.198350e-01               liquidity_log1p    -0.094139                   imbalance_1    -0.119188
# 20                   imbalance_5    -0.113027              rel_spread_log1p     0.131994             lob_depth_ratio_2    -0.155570             sell_volume_log1p    -0.141007             imbalance_depth_2     0.150225             imbalance_depth_2     0.159636                   imbalance_5     0.140825             imbalance_depth_2  1.048853e-01              sell_count_log1p     0.082695      total_trade_volume_log1p     0.102107
# 21             imbalance_depth_8    -0.105223             imbalance_depth_2     0.129525              sell_count_log1p    -0.152555          min_trade_size_log1p    -0.129571               buy_count_log1p    -0.147676          min_trade_size_log1p    -0.151713          min_trade_size_log1p    -0.139361               liquidity_log1p -8.304227e-02             lob_depth_ratio_2    -0.078351          min_trade_size_log1p    -0.080319
# 22          realized_vol_5_log1p     0.101104           trade_volume_change    -0.128809          min_trade_size_log1p    -0.143459             imbalance_depth_2     0.127976                   imbalance_5     0.136882               buy_count_log1p    -0.135266             imbalance_depth_2     0.132595           trade_volume_change -8.081287e-02             lob_depth_ratio_5     0.078307           trade_volume_change    -0.073391
# 23        trade_volume_imbalance     0.087439                   vol_5_log1p    -0.125558             sell_volume_log1p    -0.133992           trade_volume_change    -0.118898          min_trade_size_log1p    -0.132879                   imbalance_5     0.118028             sell_volume_log1p    -0.096160             imbalance_depth_5 -8.047185e-02             imbalance_depth_5    -0.073054             lob_depth_ratio_4    -0.070130
# 24             microprice_change     0.085688                  imbalance_10    -0.119418             lob_depth_ratio_5     0.132616                  imbalance_10    -0.116741           trade_volume_change    -0.118623           trade_volume_change    -0.105357       lob_bids_volume_3_log1p     0.092920       lob_bids_volume_3_log1p  7.624952e-02           trade_volume_change    -0.069996             imbalance_depth_4     0.067863
# 25       lob_bids_volume_3_log1p     0.084775             lob_depth_ratio_2    -0.107219             imbalance_depth_2     0.125826             imbalance_depth_5    -0.110723             sell_volume_log1p    -0.099935             imbalance_depth_5    -0.102821             lob_depth_ratio_3    -0.091366             sell_volume_log1p -7.553525e-02       lob_bids_volume_3_log1p     0.065399                  imbalance_10     0.066703
# 26       lob_bids_volume_8_log1p    -0.076576             imbalance_depth_4     0.095058           trade_volume_change    -0.123861                   vol_5_log1p    -0.106782       lob_bids_volume_3_log1p     0.095415       lob_bids_volume_3_log1p     0.092212           trade_volume_change    -0.086038             lob_depth_ratio_4 -7.531026e-02             imbalance_depth_4     0.064450                   imbalance_5     0.066604
# 27             lob_depth_ratio_8     0.070170            mid_price_change_1    -0.094906                    microprice     0.115030             imbalance_depth_1    -0.100764             lob_depth_ratio_3    -0.091735             lob_depth_ratio_3    -0.090912             imbalance_depth_5    -0.085725             lob_depth_ratio_5  7.425938e-02             imbalance_depth_2     0.060633             lob_depth_ratio_5     0.066586
# 28            lob_depth_ratio_10     0.063762          avg_trade_size_log1p    -0.086312        microprice_weighted_10     0.114444                   imbalance_1    -0.100764               liquidity_log1p    -0.090361             lob_depth_ratio_5     0.084319             lob_depth_ratio_4    -0.083269             imbalance_depth_4  7.253095e-02             lob_depth_ratio_4    -0.059176             sell_volume_log1p    -0.065614
# 29           trade_volume_change    -0.059282             imbalance_depth_7    -0.079678                   imbalance_5     0.104720       lob_bids_volume_3_log1p     0.091123              sell_count_log1p    -0.089290             lob_depth_ratio_4    -0.075603               liquidity_log1p    -0.073518            lob_depth_ratio_10 -4.859067e-02                  imbalance_10    -0.055976       lob_bids_volume_3_log1p     0.064395
# 30             lob_depth_ratio_7    -0.058965             lob_depth_ratio_4    -0.079314       lob_bids_volume_3_log1p     0.098295             lob_depth_ratio_5     0.085064             imbalance_depth_5    -0.080977             imbalance_depth_4     0.073922             lob_depth_ratio_5     0.072527                   imbalance_5  4.829235e-02                   imbalance_5     0.054655            lob_depth_ratio_10    -0.064112
# 31             lob_depth_ratio_9    -0.054814             microprice_change     0.077459             imbalance_depth_3     0.098172               liquidity_log1p    -0.076860             lob_depth_ratio_5     0.057547             sell_volume_log1p    -0.072128             imbalance_depth_4     0.071133             lob_depth_ratio_3 -4.829083e-02            lob_depth_ratio_10    -0.052501             imbalance_depth_5    -0.054997
# 32             lob_depth_ratio_2    -0.051976       lob_bids_volume_4_log1p    -0.068164             lob_depth_ratio_6    -0.080122       lob_bids_volume_1_log1p    -0.073121                  log_return_2    -0.055118               liquidity_log1p    -0.070024               buy_count_log1p    -0.070032              sell_count_log1p  4.370539e-02                   imbalance_1    -0.052289             lob_depth_ratio_2    -0.050486
# 33             sell_volume_log1p    -0.049845                   imbalance_1    -0.064213           mid_price_change_20    -0.064212             imbalance_depth_3     0.069882             lob_depth_ratio_4    -0.045618             imbalance_depth_9    -0.042141            lob_depth_ratio_10    -0.048950            imbalance_depth_10  4.281214e-02             imbalance_depth_1    -0.052289            imbalance_depth_10     0.049628
# 34             imbalance_depth_2     0.047824             imbalance_depth_1    -0.064213             imbalance_depth_7    -0.063974              buy_volume_log1p    -0.068206                  log_return_3     0.045569              sell_count_log1p    -0.038556            imbalance_depth_10     0.047861                  log_return_3 -3.350583e-02            imbalance_depth_10     0.049070       lob_bids_volume_1_log1p    -0.045667
# 35            mid_price_change_1    -0.047529       lob_bids_volume_3_log1p     0.055085             microprice_change     0.056652       lob_bids_volume_6_log1p     0.066517             imbalance_depth_4     0.042098                  log_return_3     0.036059             imbalance_depth_9    -0.032933              buy_volume_log1p -3.204800e-02             lob_depth_ratio_3    -0.037716               buy_count_log1p     0.043403
# 36               liquidity_log1p    -0.046499                  log_return_2    -0.046419     total_bid_volume_10_log1p    -0.048651             lob_depth_ratio_4    -0.055851             imbalance_depth_9    -0.040335             imbalance_depth_6    -0.035509             imbalance_depth_6    -0.031287       lob_bids_volume_6_log1p  2.901435e-02        trade_volume_imbalance     0.035871        trade_volume_imbalance     0.042399
# 37                  log_return_1     0.043771             lob_depth_ratio_7     0.046200             lob_depth_ratio_7     0.046378                  log_return_2    -0.049312             imbalance_depth_6    -0.037241                  log_return_2    -0.032488             imbalance_depth_3     0.030779       lob_bids_volume_2_log1p  2.810761e-02             sell_volume_log1p    -0.035519  lag_trade_volume_imbalance_1     0.039557
# 38                  log_return_3     0.038967             imbalance_depth_9    -0.045385       lob_bids_volume_6_log1p     0.045970             imbalance_depth_9    -0.043638  lag_trade_volume_imbalance_5     0.033514             imbalance_depth_3     0.030804       lob_bids_volume_8_log1p    -0.030767        trade_volume_imbalance  2.736172e-02             imbalance_depth_9    -0.032386       lob_bids_volume_6_log1p     0.033936
# 39       lob_bids_volume_4_log1p    -0.038353             imbalance_depth_8    -0.044463             imbalance_depth_9    -0.039317             imbalance_depth_4     0.041314             imbalance_depth_8     0.033397            lob_depth_ratio_10    -0.029141            mid_price_change_1    -0.030430       lob_bids_volume_8_log1p -2.689391e-02  lag_trade_volume_imbalance_1     0.029618             imbalance_depth_2     0.026432
# 40              sell_count_log1p    -0.036297            mid_price_change_5    -0.043358            mid_price_change_1    -0.037754             lob_depth_ratio_6    -0.041154       lob_bids_volume_6_log1p     0.030067        trade_volume_imbalance     0.028178              buy_volume_log1p    -0.029290            mid_price_change_1 -2.641394e-02       lob_bids_volume_8_log1p    -0.028923             imbalance_depth_3    -0.024583
# 41             lob_depth_ratio_6    -0.035906            imbalance_depth_10    -0.043016             imbalance_depth_4     0.035425             imbalance_depth_8     0.038839            mid_price_change_1    -0.028595       lob_bids_volume_8_log1p    -0.026830       lob_bids_volume_2_log1p     0.027088             imbalance_depth_6 -2.524040e-02                   vol_5_log1p    -0.028833            mid_price_change_1    -0.023850
# 42                   vol_5_log1p    -0.035339           mid_price_change_20     0.041759       lob_bids_volume_5_log1p    -0.032630  lag_trade_volume_imbalance_5     0.036092            lob_depth_ratio_10    -0.026364           mid_price_change_20     0.026405           mid_price_change_20     0.026455                   imbalance_1 -2.453658e-02       lob_bids_volume_6_log1p     0.026444                   vol_5_log1p    -0.023144
# 43                  spread_log1p    -0.033527             sell_volume_log1p    -0.040388                  log_return_2    -0.031644       lob_bids_volume_2_log1p     0.031581            imbalance_depth_10     0.023474       lob_bids_volume_4_log1p    -0.025263        trade_volume_imbalance     0.025380             imbalance_depth_1 -2.453658e-02            mid_price_change_1    -0.019245                  log_return_1     0.022993
# 44       lob_bids_volume_2_log1p    -0.033214        trade_volume_imbalance     0.039873  lag_trade_volume_imbalance_5     0.030929                  log_return_5     0.027483       lob_bids_volume_2_log1p     0.021300       lob_bids_volume_2_log1p     0.023308       lob_bids_volume_6_log1p     0.022869  lag_trade_volume_imbalance_1  2.331438e-02                  log_return_3    -0.019093              buy_volume_log1p    -0.022877
# 45             imbalance_depth_6     0.031084       lob_bids_volume_8_log1p    -0.039156             imbalance_depth_6     0.026009       momentum_5_log_return_1     0.027483  lag_trade_volume_imbalance_1     0.021173            imbalance_depth_10     0.023149       lob_bids_volume_5_log1p    -0.021829               buy_count_log1p -2.122671e-02               buy_count_log1p     0.018867       lob_bids_volume_9_log1p     0.022691
# 46       lob_bids_volume_6_log1p     0.026243     total_bid_volume_10_log1p     0.037509       momentum_5_log_return_1     0.023967  lag_trade_volume_imbalance_1     0.027055      lob_bids_volume_10_log1p    -0.019756                  spread_log1p    -0.023103                  log_return_2    -0.021430                  log_return_5  1.980913e-02       lob_bids_volume_5_log1p    -0.017956           mid_price_change_20     0.021123
# 47             imbalance_depth_9     0.023979             lob_depth_ratio_8     0.035843                  log_return_5     0.023967             lob_depth_ratio_8    -0.024123             lob_depth_ratio_6     0.019246       lob_bids_volume_6_log1p     0.021087                  spread_log1p    -0.019952       momentum_5_log_return_1  1.980913e-02           mid_price_change_20     0.017275             lob_depth_ratio_3    -0.020677
# 48      momentum_20_log_return_1     0.023762      lob_bids_volume_10_log1p    -0.029622             lob_depth_ratio_4    -0.022564             imbalance_depth_7    -0.023703           mid_price_change_20     0.019054       lob_bids_volume_5_log1p    -0.020907  lag_trade_volume_imbalance_1     0.019378                  spread_log1p -1.930357e-02       momentum_5_log_return_1     0.016922       lob_bids_volume_7_log1p    -0.018395
# 49                 log_return_20     0.023762                  spread_log1p     0.025658                  log_return_3    -0.020955             microprice_change     0.022236             lob_depth_ratio_9     0.018478      lob_bids_volume_10_log1p    -0.020383      lob_bids_volume_10_log1p    -0.018485                   vol_5_log1p -1.685709e-02                  log_return_5     0.016922             imbalance_depth_9    -0.017656
# 50  lag_trade_volume_imbalance_1    -0.020494  lag_trade_volume_imbalance_3    -0.025575       lob_bids_volume_2_log1p     0.020918  lag_trade_volume_imbalance_3    -0.021816                  spread_log1p    -0.017696             lob_depth_ratio_6     0.019387       lob_bids_volume_4_log1p    -0.016926             imbalance_depth_9 -1.665010e-02       lob_bids_volume_9_log1p     0.016325       momentum_5_log_return_1     0.017121
# 51  lag_trade_volume_imbalance_5     0.019387       lob_bids_volume_7_log1p    -0.024019  lag_trade_volume_imbalance_1     0.019195             lob_depth_ratio_9     0.020213             imbalance_depth_3     0.017544            mid_price_change_1    -0.019308             lob_depth_ratio_7    -0.014517                  imbalance_10 -1.637929e-02      lob_bids_volume_10_log1p    -0.016197                  log_return_5     0.017121
# 52       lob_bids_volume_7_log1p    -0.018177  lag_trade_volume_imbalance_5     0.022464            lob_depth_ratio_10    -0.016901       lob_bids_volume_5_log1p    -0.018323       lob_bids_volume_4_log1p    -0.016687             imbalance_depth_8     0.017281       momentum_5_log_return_1     0.013508                  log_return_2  1.616926e-02                  spread_log1p    -0.014100       lob_bids_volume_2_log1p     0.016914
# 53             imbalance_depth_7    -0.016098             lob_depth_ratio_9     0.021611        trade_volume_imbalance     0.016008                  spread_log1p    -0.014729             lob_depth_ratio_8    -0.014344  lag_trade_volume_imbalance_5     0.016926                  log_return_5     0.013508           mid_price_change_20  1.508785e-02             imbalance_depth_8    -0.013510                  log_return_3    -0.015510
# 54       lob_bids_volume_5_log1p    -0.014380                  log_return_3     0.017457  lag_trade_volume_imbalance_3    -0.012065       lob_bids_volume_9_log1p     0.013104       lob_bids_volume_5_log1p    -0.013940  lag_trade_volume_imbalance_1     0.016550                  log_return_1     0.012633             lob_depth_ratio_9 -1.391786e-02             imbalance_depth_6    -0.013418                  spread_log1p    -0.014486
# 55  lag_trade_volume_imbalance_2     0.013005       momentum_5_log_return_1     0.017033             lob_depth_ratio_8     0.011266            mid_price_change_5    -0.012375        trade_volume_imbalance     0.013688             imbalance_depth_7    -0.015779                   vol_5_log1p     0.010992             lob_depth_ratio_7 -1.367057e-02                  log_return_1     0.013307       lob_bids_volume_5_log1p    -0.013046
# 56                    microprice    -0.012421                  log_return_5     0.017033            imbalance_depth_10    -0.009799             imbalance_depth_6    -0.011503  lag_trade_volume_imbalance_3    -0.012207         mid_minus_micro_log1p    -0.008820  lag_trade_volume_imbalance_5     0.007731  lag_trade_volume_imbalance_3  1.317208e-02       lob_bids_volume_7_log1p    -0.011934  lag_trade_volume_imbalance_5     0.009980
# 57          avg_trade_size_log1p     0.009408  lag_trade_volume_imbalance_1     0.015332             imbalance_depth_8    -0.009478           mid_price_change_20     0.007683            mid_price_change_5     0.009589       lob_bids_volume_7_log1p    -0.008253  lag_trade_volume_imbalance_3     0.006968       lob_bids_volume_9_log1p  1.203100e-02       lob_bids_volume_2_log1p     0.011519       lob_bids_volume_4_log1p     0.008826
# 58        microprice_weighted_10    -0.006796             imbalance_depth_6    -0.015153       lob_bids_volume_8_log1p    -0.008325            imbalance_depth_10    -0.007613       lob_bids_volume_7_log1p    -0.009474       lob_bids_volume_9_log1p    -0.008231             lob_depth_ratio_6     0.006457      lob_bids_volume_10_log1p -1.109339e-02  lag_trade_volume_imbalance_5     0.011033  lag_trade_volume_imbalance_2     0.008599
# 59                  log_return_2    -0.005113       lob_bids_volume_5_log1p    -0.015011      momentum_20_log_return_1    -0.008132            mid_price_change_1    -0.007576       lob_bids_volume_8_log1p    -0.008418             lob_depth_ratio_9     0.007758                  log_return_3     0.006166       lob_bids_volume_7_log1p -9.344029e-03             lob_depth_ratio_8     0.009715             imbalance_depth_8    -0.007556
# 60      lob_bids_volume_10_log1p    -0.005073       lob_bids_volume_2_log1p    -0.014628                 log_return_20    -0.008132      lob_bids_volume_10_log1p     0.006038             imbalance_depth_7    -0.008378             lob_depth_ratio_8    -0.005751             lob_depth_ratio_9     0.004248       lob_bids_volume_4_log1p -6.994617e-03  lag_trade_volume_imbalance_2     0.009223             lob_depth_ratio_6    -0.006776
# 61             imbalance_depth_3    -0.003817             imbalance_depth_3     0.014497                  spread_log1p     0.006406            lob_depth_ratio_10    -0.005410              buy_volume_log1p    -0.008162      momentum_20_log_return_1     0.005059  lag_trade_volume_imbalance_2     0.004121                  log_return_1  5.986361e-03             imbalance_depth_3    -0.008722  lag_trade_volume_imbalance_3     0.006184
# 62       lob_bids_volume_9_log1p    -0.001016       lob_bids_volume_9_log1p    -0.012623       lob_bids_volume_9_log1p    -0.006082             lob_depth_ratio_7     0.004762                 log_return_20     0.007734                 log_return_20     0.005059             lob_depth_ratio_8     0.003940            mid_price_change_5 -5.214211e-03              buy_volume_log1p    -0.007561             lob_depth_ratio_7    -0.004758
# 63       momentum_5_log_return_1    -0.000564       lob_bids_volume_6_log1p    -0.006843       lob_bids_volume_7_log1p    -0.005410  lag_trade_volume_imbalance_2     0.003820      momentum_20_log_return_1     0.007734                   vol_5_log1p     0.004028                 log_return_20    -0.003480  lag_trade_volume_imbalance_2  3.907446e-03             imbalance_depth_7    -0.007076             lob_depth_ratio_9    -0.003052
# 64                  log_return_5    -0.000564            lob_depth_ratio_10     0.005638       lob_bids_volume_4_log1p    -0.005325        trade_volume_imbalance     0.002931       momentum_5_log_return_1     0.004298                  log_return_5     0.003916      momentum_20_log_return_1    -0.003480                 log_return_20 -3.266681e-03             lob_depth_ratio_7    -0.006588             imbalance_depth_6    -0.002478
# 65                   imbalance_1     0.000000                 log_return_20     0.004488      lob_bids_volume_10_log1p     0.004766      momentum_20_log_return_1     0.002843                  log_return_5     0.004298       momentum_5_log_return_1     0.003916            mid_price_change_5    -0.002859      momentum_20_log_return_1 -3.266681e-03  lag_trade_volume_imbalance_3     0.006134                  log_return_2    -0.001849
# 66             imbalance_depth_1     0.000000      momentum_20_log_return_1     0.004488            mid_price_change_5    -0.001744                 log_return_20     0.002843             microprice_change     0.003945                  log_return_1     0.002211       lob_bids_volume_7_log1p    -0.002788       lob_bids_volume_5_log1p -3.196684e-03            mid_price_change_5    -0.004164            mid_price_change_5    -0.001368
# 67  lag_trade_volume_imbalance_3     0.000000               liquidity_log1p     0.002331  lag_trade_volume_imbalance_2     0.000274       lob_bids_volume_7_log1p     0.001317             lob_depth_ratio_7    -0.000953             lob_depth_ratio_7     0.002001       lob_bids_volume_9_log1p     0.001586             lob_depth_ratio_6  3.116105e-03             lob_depth_ratio_9     0.002955       lob_bids_volume_8_log1p    -0.001358
# 68                  imbalance_10     0.000000  lag_trade_volume_imbalance_2     0.001232             lob_depth_ratio_9     0.000000                  log_return_3    -0.001113  lag_trade_volume_imbalance_2    -0.000779            mid_price_change_5     0.001801             imbalance_depth_7     0.001431             imbalance_depth_8  2.339257e-03       lob_bids_volume_4_log1p    -0.002690      lob_bids_volume_10_log1p     0.001192
# 69     total_bid_volume_10_log1p     0.000000                   imbalance_5     0.000000                   imbalance_1     0.000000       lob_bids_volume_4_log1p    -0.000505       lob_bids_volume_9_log1p    -0.000407  lag_trade_volume_imbalance_3    -0.001700             imbalance_depth_8    -0.000597  lag_trade_volume_imbalance_5  9.207185e-04      momentum_20_log_return_1    -0.002681      momentum_20_log_return_1    -0.000956
# 70              rel_spread_log1p     0.000000             lob_depth_ratio_6     0.000000                  log_return_1     0.000000                  log_return_1     0.000000                   imbalance_1     0.000000  lag_trade_volume_imbalance_2     0.001458                   imbalance_1     0.000000             imbalance_depth_7 -8.893713e-04                 log_return_20    -0.002681                 log_return_20    -0.000956
# 71         mid_minus_micro_log1p     0.000000        microprice_weighted_10     0.000000             imbalance_depth_1     0.000000        microprice_weighted_10     0.000000             imbalance_depth_1     0.000000              buy_volume_log1p    -0.000733             imbalance_depth_1     0.000000         mid_minus_micro_log1p  1.052691e-08                  log_return_2     0.000309             lob_depth_ratio_8     0.000000
# 72                  vol_20_log1p     0.000000                    microprice     0.000000               liquidity_log1p     0.000000                    microprice     0.000000                  log_return_1     0.000000                   imbalance_1     0.000000             microprice_change     0.000000             lob_depth_ratio_8  0.000000e+00             lob_depth_ratio_6     0.000000             microprice_change     0.000000
# 73      total_trade_volume_log1p     0.000000                  log_return_1     0.000000         mid_minus_micro_log1p     0.000000       lob_bids_volume_8_log1p     0.000000                   vol_5_log1p     0.000000             imbalance_depth_1     0.000000              sell_count_log1p     0.000000             imbalance_depth_3  0.000000e+00             microprice_change     0.000000             imbalance_depth_7     0.000000
# 74              buy_volume_log1p     0.000000         mid_minus_micro_log1p     0.000000              buy_volume_log1p     0.000000         mid_minus_micro_log1p     0.000000         mid_minus_micro_log1p     0.000000             microprice_change     0.000000         mid_minus_micro_log1p     0.000000             microprice_change  0.000000e+00         mid_minus_micro_log1p     0.000000         mid_minus_micro_log1p     0.000000

# %%
from prettytable import PrettyTable

for i in range(len(sorted_tables)):
    df = sorted_tables[i].round(4)

    table = PrettyTable()
    table.field_names = ["feature", "coef"]

    for row in df.values:
        table.add_row(row)

    with open(
        f"C:\\Users\\jayod\\Documents\\Quant_Project\\microstructure-alpha-engine\\notebooks\\saved_info\\l1_fold\\fold_{i}.txt",
        "w",
    ) as f:
        f.write(str(table))

# %%
from prettytable import PrettyTable

table = PrettyTable()
table.field_names = ["feature", "avg_coef"]

for feature, coef in avg_coefs.round(4).items():
    table.add_row([feature, coef])

with open(
    "C:\\Users\\jayod\\Documents\\Quant_Project\\microstructure-alpha-engine\\notebooks\\saved_info\\l1_fold\\avg.txt",
    "w",
) as f:
    f.write(str(table))
